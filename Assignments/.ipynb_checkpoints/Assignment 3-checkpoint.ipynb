# %%
# Python ≥3.5 is required
import sys

# Scikit-Learn ≥0.20 is required
import sklearn
import seaborn as sns

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Where to save the figures for this lecture(s) only. The first few variables will use functions from OS module that you just imported.
# You will also create folders where the files from various plots will be saved.

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "Homework_3"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import pandas as pd
TITANIC_PATH = os.path.join(".", "datasets", "titanic");

def load_titanic_data(titanic_path):
    csv_path = os.path.join(TITANIC_PATH, titanic_path)
    return pd.read_csv(csv_path)

# %%
titanic = load_titanic_data("train.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.hist(bins=50, figsize=(20,15))
save_fig("titanic_histogram_plots")
plt.show()
# Out:
# Saving figure titanic_histogram_plots

# %%
titanic["Age"].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# There is a skew in a Age varibale of 30%. that is why i am using median to analyse the age.

# %%
titanic.groupby(['Pclass','Survived'])['Age'].median()
# Out:
# Pclass  Survived
# 1       0           45.25
#         1           35.00
# 2       0           30.50
#         1           28.00
# 3       0           25.00
#         1           22.00
# Name: Age, dtype: float64

# %%
sns.catplot('Pclass','Age',hue='Survived', kind='bar', data=titanic);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic_x = titanic.drop("Survived", axis=1) # drop labels for training set
titanic_y = titanic["Survived"].copy()

# %%
titanic_x = titanic_x.set_index("PassengerId")

# %%
titanic_x
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# ...             ...                                                ...
# 887               2                              Montvila, Rev. Juozas
# 888               1                       Graham, Miss. Margaret Edith
# 889               3           Johnston, Miss. Catherine Helen "Carrie"
# 890               1                              Behr, Mr. Karl Howell
# 891               3                                Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
titanic_y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
sample_incomplete_rows = titanic_x[titanic_x.isnull().any(axis=1)].head()
sample_incomplete_rows
# Out:
#              Pclass                            Name     Sex   Age  SibSp  \
# PassengerId
# 1                 3         Braund, Mr. Owen Harris    male  22.0      1
# 3                 3          Heikkinen, Miss. Laina  female  26.0      0
# 5                 3        Allen, Mr. William Henry    male  35.0      0
# 6                 3                Moran, Mr. James    male   NaN      0
# 8                 3  Palsson, Master. Gosta Leonard    male   2.0      3
#
#              Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S
# 3                0  STON/O2. 3101282   7.9250   NaN        S
# 5                0            373450   8.0500   NaN        S
# 6                0            330877   8.4583   NaN        Q
# 8                1            349909  21.0750   NaN        S

# %%
titanic_x = titanic_x.drop(["Name","Ticket","Cabin"], axis=1)

# %%
titanic_x
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0   7.2500        S
# 2                 1  female  38.0      1      0  71.2833        C
# 3                 3  female  26.0      0      0   7.9250        S
# 4                 1  female  35.0      1      0  53.1000        S
# 5                 3    male  35.0      0      0   8.0500        S
# ...             ...     ...   ...    ...    ...      ...      ...
# 887               2    male  27.0      0      0  13.0000        S
# 888               1  female  19.0      0      0  30.0000        S
# 889               3  female   NaN      1      2  23.4500        S
# 890               1    male  26.0      0      0  30.0000        C
# 891               3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

# %%
titanic_x["Age"]=imputer.fit_transform(titanic_x[["Age"]])

# %%
titanic_x["Age"].isnull().sum()
# Out:
# 0

# %%
titanic_x["Fare"]=imputer.fit_transform(titanic_x[["Fare"]])

# %%
titanic_x["Fare"].isnull().sum()
# Out:
# 0

# %%
titanic_x
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0   7.2500        S
# 2                 1  female  38.0      1      0  71.2833        C
# 3                 3  female  26.0      0      0   7.9250        S
# 4                 1  female  35.0      1      0  53.1000        S
# 5                 3    male  35.0      0      0   8.0500        S
# ...             ...     ...   ...    ...    ...      ...      ...
# 887               2    male  27.0      0      0  13.0000        S
# 888               1  female  19.0      0      0  30.0000        S
# 889               3  female  28.0      1      2  23.4500        S
# 890               1    male  26.0      0      0  30.0000        C
# 891               3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
titanic_x["Embarked"].isnull().sum()
# Out:
# 2

# %%
titanic_x["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic_x["Embarked"]=titanic_x["Embarked"].fillna('S')

# %%
titanic_x
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0   7.2500        S
# 2                 1  female  38.0      1      0  71.2833        C
# 3                 3  female  26.0      0      0   7.9250        S
# 4                 1  female  35.0      1      0  53.1000        S
# 5                 3    male  35.0      0      0   8.0500        S
# ...             ...     ...   ...    ...    ...      ...      ...
# 887               2    male  27.0      0      0  13.0000        S
# 888               1  female  19.0      0      0  30.0000        S
# 889               3  female  28.0      1      2  23.4500        S
# 890               1    male  26.0      0      0  30.0000        C
# 891               3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
titanic_x["Embarked"].isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
titanic_encoder = LabelEncoder()
titanic_x["Sex"] = titanic_encoder.fit_transform(titanic_x[["Sex"]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
titanic_x
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                 3    1  22.0      1      0   7.2500        S
# 2                 1    0  38.0      1      0  71.2833        C
# 3                 3    0  26.0      0      0   7.9250        S
# 4                 1    0  35.0      1      0  53.1000        S
# 5                 3    1  35.0      0      0   8.0500        S
# ...             ...  ...   ...    ...    ...      ...      ...
# 887               2    1  27.0      0      0  13.0000        S
# 888               1    0  19.0      0      0  30.0000        S
# 889               3    0  28.0      1      2  23.4500        S
# 890               1    1  26.0      0      0  30.0000        C
# 891               3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
titanic_encoder = LabelEncoder()
titanic_x["Embarked"] = titanic_encoder.fit_transform(titanic_x[["Embarked"]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
titanic_x
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 1                 3    1  22.0      1      0   7.2500         2
# 2                 1    0  38.0      1      0  71.2833         0
# 3                 3    0  26.0      0      0   7.9250         2
# 4                 1    0  35.0      1      0  53.1000         2
# 5                 3    1  35.0      0      0   8.0500         2
# ...             ...  ...   ...    ...    ...      ...       ...
# 887               2    1  27.0      0      0  13.0000         2
# 888               1    0  19.0      0      0  30.0000         2
# 889               3    0  28.0      1      2  23.4500         2
# 890               1    1  26.0      0      0  30.0000         0
# 891               3    1  32.0      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

# %%
log_reg.fit(titanic_x, titanic_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import pandas as pd
TITANIC_PATH = os.path.join(".", "datasets", "titanic");

def load_titanic_data(titanic_path):
    csv_path = os.path.join(TITANIC_PATH, titanic_path)
    return pd.read_csv(csv_path)

titanic_test = load_titanic_data("test.csv")
titanic_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic_test["Age"].isnull().sum()
# Out:
# 86

# %%
train_median_age = titanic["Age"].median()
train_median_fare = titanic["Fare"].median()

# %%
titanic_test["Age"].fillna(train_median_age,inplace=True)
titanic_test["Fare"].fillna(train_median_fare,inplace=True)

# %%
titanic_test = titanic_test.drop(["Name","Ticket","Cabin"],axis=1)

# %%
titanic_test
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male  28.0      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male  28.0      0      0    8.0500        S
# 417         1309       3    male  28.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
titanic_test["Sex"] = titanic_encoder.fit_transform(titanic_test[["Sex"]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
titanic_test["Embarked"] = titanic_encoder.fit_transform(titanic_test[["Embarked"]])

# %%
titanic_test = titanic_test.set_index("PassengerId")

# %%
titanic_test
# Out:
#              Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# PassengerId
# 892               3    1  34.5      0      0    7.8292         1
# 893               3    0  47.0      1      0    7.0000         2
# 894               2    1  62.0      0      0    9.6875         1
# 895               3    1  27.0      0      0    8.6625         2
# 896               3    0  22.0      1      1   12.2875         2
# ...             ...  ...   ...    ...    ...       ...       ...
# 1305              3    1  28.0      0      0    8.0500         2
# 1306              1    0  39.0      0      0  108.9000         0
# 1307              3    1  38.5      0      0    7.2500         2
# 1308              3    1  28.0      0      0    8.0500         2
# 1309              3    1  28.0      1      1   22.3583         0
#
# [418 rows x 7 columns]

# %%
y_pred = log_reg.predict(titanic_test)

# %%
y_test = load_titanic_data("gender_submission.csv")["Survived"]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9401913875598086
